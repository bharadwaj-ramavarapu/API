# %% [markdown]
# # API:
# API is an acronym for Application Programming Interface which help us to access data, server software or other applications by allowing pieces of code to interact with one another

# %% [markdown]
# In this project I'm using an api to get the data from a server

# %% [markdown]
# ### This markdown cell contains the steps that I've used
# step1:importing request library to make Api requests,pandas library for dataframe
#
# In this project we using the TMBD website's database so we requesting this website Api for the data for which we need an API key. (https://www.themoviedb.org/)
#
# Step2:requesting an api key which give us access to that api
# ### steps for an api key
# 1)make an TMDB account
#
# 2)In setting pages under Api tab there is an option for making an Api key fill out the details and Api key will be availablein a couple of minutes
#
# Step3: On developers website you will have the response url which will get the data.
#
# Step4: convert this into .json flie and save this to a dataframe
#
# Step5: convert this into .csv file

# %%
#import libraries
import requests
import pandas as pd

# %%
#Keys
API_KEY = "9d550519bc6f119d38bfcc9f31333732"

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=9d550519bc6f119d38bfcc9f31333732&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3  19404  Dilwale Dulhania Le Jayenge
# 4    424             Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     102.565
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     109.622
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      68.952
# 3  Raj is a rich, carefree, happy-go-lucky second...   1995-10-19      30.344
# 4  The true story of how businessman Oskar Schind...   1993-12-15      74.021
#
#    vote_average  vote_count
# 0           8.7       16790
# 1           8.7       22518
# 2           8.6       10174
# 3           8.6        3920
# 4           8.6       13367

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# one run of this code will give us single page data so make a for loop for 100 pages and save this data fin df dataframe

# %%
for i in range(1,100):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#           id                                              title  \
# 0        238                                      The Godfather
# 1        278                           The Shawshank Redemption
# 2        240                              The Godfather Part II
# 3      19404                        Dilwale Dulhania Le Jayenge
# 4        424                                   Schindler's List
# ...      ...                                                ...
# 1975    6619                                    Death in Venice
# 1976     180                                    Minority Report
# 1977  283591                               The Secret Scripture
# 1978   18874  Ghost in the Shell: Stand Alone Complex – Soli...
# 1979   15003                                          Chocolate
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# ...

# %%
df.shape
# Out:
# (1980, 7)

# %% [markdown]
# convert this data into csv file

# %%
df.to_csv('movies.csv')
